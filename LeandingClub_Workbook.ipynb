# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv("data/LendingClub_data.csv", nrows=10000)
df.to_csv('dataBite.csv')
#df = df[sorted(df)]

# %%
pd.set_option('display.max_columns', None)
df.head()
# Out:
#          id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  68407277        NaN     3600.0       3600.0           3600.0   36 months
# 1  68355089        NaN    24700.0      24700.0          24700.0   36 months
# 2  68341763        NaN    20000.0      20000.0          20000.0   60 months
# 3  66310712        NaN    35000.0      35000.0          35000.0   60 months
# 4  68476807        NaN    10400.0      10400.0          10400.0   60 months
#
#    int_rate  installment grade sub_grade                    emp_title  \
# 0     13.99       123.03     C        C4                      leadman
# 1     11.99       820.28     C        C1                     Engineer
# 2     10.78       432.66     B        B4                 truck driver
# 3     14.85       829.90     C        C5  Information Systems Officer
# 4     22.45       289.91     F        F1          Contract Specialist
#
#   emp_length home_ownership  annual_inc verification_status   issue_d  \
# 0  10+ years       MORTGAGE     55000.0        Not Verified  Dec-2015
# 1  10+ years       MORTGAGE     65000.0        Not Verified  Dec-2015
# 2  10+ years       MORTGAGE     63000.0        Not Verified  Dec-2015
# 3  10+ years       MORTGAGE    110000.0     Source Verified  Dec-2015
# 4    3 years       MORTGAGE    104433.0     Source Verified  Dec-2015
#
#   loan_status pymnt_plan                                                url  \
# 0  Fully Paid          n  https://lendingclub.com/browse/loanDetail.acti...
# 1  Fully Paid          n  https://lendingclub.com/browse/loanDetail.acti...
# 2  Fully Paid          n  https://lendingclub.com/browse/loanDetail.acti...
# 3     Current          n  https://lendingclub.com/browse/loanDetail.acti...
# 4  Fully Paid          n  https://lendingclub.com/browse/loanDetail.acti...
#
#   desc             purpose               title zip_code addr_state    dti  \
# 0  NaN  debt_consolidation  Debt consolidation    190xx         PA   5.91
# 1  NaN      small_business            Business    577xx         SD  16.06
# 2  NaN    home_improvement                 NaN    605xx         IL  10.78
# 3  NaN  debt_consolidation  Debt consolidation    076xx         NJ  17.06
# 4  NaN      major_purchase      Major purchase    174xx         PA  25.37
#
#    delinq_2yrs earliest_cr_line  fico_range_low  fico_range_high  \
# 0          0.0         Aug-2003           675.0            679.0
# 1          1.0         Dec-1999           715.0            719.0
# 2          0.0         Aug-2000           695.0            699.0
# 3          0.0         Sep-2008           785.0            789.0
# 4          1.0         Jun-1998           695.0            699.0
#
#    inq_last_6mths  mths_since_last_delinq  mths_since_last_record  open_acc  \
# 0             1.0                    30.0                     NaN       7.0
# 1             4.0                     6.0                     NaN      22.0
# 2             0.0                     NaN                     NaN       6.0
# 3             0.0                     NaN                     NaN      13.0
# 4             3.0                    12.0                     NaN      12.0
#
#    pub_rec  revol_bal  revol_util  total_acc initial_list_status  out_prncp  \
# 0      0.0     2765.0        29.7       13.0                   w       0.00
# 1      0.0    21470.0        19.2       38.0                   w       0.00
# 2      0.0     7869.0        56.2       18.0                   w       0.00
# 3      0.0     7802.0        11.6       17.0                   w   15897.65
# 4      0.0    21929.0        64.5       35.0                   w       0.00
#
#    out_prncp_inv   total_pymnt  total_pymnt_inv  total_rec_prncp  \
# 0           0.00   4421.723917          4421.72          3600.00
# 1           0.00  25679.660000         25679.66         24700.00
# 2           0.00  22705.924294         22705.92         20000.00
# 3       15897.65  31464.010000         31464.01         19102.35
# 4           0.00  11740.500000         11740.50         10400.00
#
#    total_rec_int  total_rec_late_fee  recoveries  collection_recovery_fee  \
# 0         821.72                 0.0         0.0                      0.0
# 1         979.66                 0.0         0.0                      0.0
# 2        2705.92                 0.0         0.0                      0.0
# 3       12361.66                 0.0         0.0                      0.0
# 4        1340.50                 0.0         0.0                      0.0
#
#   last_pymnt_d  last_pymnt_amnt next_pymnt_d last_credit_pull_d  \
# 0     Jan-2019           122.67          NaN           Mar-2019
# 1     Jun-2016           926.35          NaN           Mar-2019
# 2     Jun-2017         15813.30          NaN           Mar-2019
# 3     Feb-2019           829.90     Apr-2019           Mar-2019
# 4     Jul-2016         10128.96          NaN           Mar-2018
#
#    last_fico_range_high  last_fico_range_low  collections_12_mths_ex_med  \
# 0                 564.0                560.0                         0.0
# 1                 699.0                695.0                         0.0
# 2                 704.0                700.0                         0.0
# 3                 679.0                675.0                         0.0
# 4                 704.0                700.0                         0.0
#
#    mths_since_last_major_derog  policy_code application_type  \
# 0                         30.0          1.0       Individual
# 1                          NaN          1.0       Individual
# 2                          NaN          1.0        Joint App
# 3                          NaN          1.0       Individual
# 4                          NaN          1.0       Individual
#
#    annual_inc_joint  dti_joint verification_status_joint  acc_now_delinq  \
# 0               NaN        NaN                       NaN             0.0
# 1               NaN        NaN                       NaN             0.0
# 2           71000.0      13.85              Not Verified             0.0
# 3               NaN        NaN                       NaN             0.0
# 4               NaN        NaN                       NaN             0.0
#
#    tot_coll_amt  tot_cur_bal  open_acc_6m  open_act_il  open_il_12m  \
# 0         722.0     144904.0          2.0          2.0          0.0
# 1           0.0     204396.0          1.0          1.0          0.0
# 2           0.0     189699.0          0.0          1.0          0.0
# 3           0.0     301500.0          1.0          1.0          0.0
# 4           0.0     331730.0          1.0          3.0          0.0
#
#    open_il_24m  mths_since_rcnt_il  total_bal_il  il_util  open_rv_12m  \
# 0          1.0                21.0        4981.0     36.0          3.0
# 1          1.0                19.0       18005.0     73.0          2.0
# 2          4.0                19.0       10827.0     73.0          0.0
# 3          1.0                23.0       12609.0     70.0          1.0
# 4          3.0                14.0       73839.0     84.0          4.0
#
#    open_rv_24m  max_bal_bc  all_util  total_rev_hi_lim  inq_fi  total_cu_tl  \
# 0          3.0       722.0      34.0            9300.0     3.0          1.0
# 1          3.0      6472.0      29.0          111800.0     0.0          0.0
# 2          2.0      2081.0      65.0           14000.0     2.0          5.0
# 3          1.0      6987.0      45.0           67300.0     0.0          1.0
# 4          7.0      9702.0      78.0           34000.0     2.0          1.0
#
#    inq_last_12m  acc_open_past_24mths  avg_cur_bal  bc_open_to_buy  bc_util  \
# 0           4.0                   4.0      20701.0          1506.0     37.2
# 1           6.0                   4.0       9733.0         57830.0     27.1
# 2           1.0                   6.0      31617.0          2737.0     55.9
# 3           0.0                   2.0      23192.0         54962.0     12.1
# 4           3.0                  10.0      27644.0          4567.0     77.5
#
#    chargeoff_within_12_mths  delinq_amnt  mo_sin_old_il_acct  \
# 0                       0.0          0.0               148.0
# 1                       0.0          0.0               113.0
# 2                       0.0          0.0               125.0
# 3                       0.0          0.0                36.0
# 4                       0.0          0.0               128.0
#
#    mo_sin_old_rev_tl_op  mo_sin_rcnt_rev_tl_op  mo_sin_rcnt_tl  mort_acc  \
# 0                 128.0                    3.0             3.0       1.0
# 1                 192.0                    2.0             2.0       4.0
# 2                 184.0                   14.0            14.0       5.0
# 3                  87.0                    2.0             2.0       1.0
# 4                 210.0                    4.0             4.0       6.0
#
#    mths_since_recent_bc  mths_since_recent_bc_dlq  mths_since_recent_inq  \
# 0                   4.0                      69.0                    4.0
# 1                   2.0                       NaN                    0.0
# 2                 101.0                       NaN                   10.0
# 3                   2.0                       NaN                    NaN
# 4                   4.0                      12.0                    1.0
#
#    mths_since_recent_revol_delinq  num_accts_ever_120_pd  num_actv_bc_tl  \
# 0                            69.0                    2.0             2.0
# 1                             6.0                    0.0             5.0
# 2                             NaN                    0.0             2.0
# 3                             NaN                    0.0             4.0
# 4                            12.0                    0.0             4.0
#
#    num_actv_rev_tl  num_bc_sats  num_bc_tl  num_il_tl  num_op_rev_tl  \
# 0              4.0          2.0        5.0        3.0            4.0
# 1              5.0         13.0       17.0        6.0           20.0
# 2              3.0          2.0        4.0        6.0            4.0
# 3              5.0          8.0       10.0        2.0           10.0
# 4              6.0          5.0        9.0       10.0            7.0
#
#    num_rev_accts  num_rev_tl_bal_gt_0  num_sats  num_tl_120dpd_2m  \
# 0            9.0                  4.0       7.0               0.0
# 1           27.0                  5.0      22.0               0.0
# 2            7.0                  3.0       6.0               0.0
# 3           13.0                  5.0      13.0               0.0
# 4           19.0                  6.0      12.0               0.0
#
#    num_tl_30dpd  num_tl_90g_dpd_24m  num_tl_op_past_12m  pct_tl_nvr_dlq  \
# 0           0.0                 0.0                 3.0            76.9
# 1           0.0                 0.0                 2.0            97.4
# 2           0.0                 0.0                 0.0           100.0
# 3           0.0                 0.0                 1.0           100.0
# 4           0.0                 0.0                 4.0            96.6
#
#    percent_bc_gt_75  pub_rec_bankruptcies  tax_liens  tot_hi_cred_lim  \
# 0               0.0                   0.0        0.0         178050.0
# 1               7.7                   0.0        0.0         314017.0
# 2              50.0                   0.0        0.0         218418.0
# 3               0.0                   0.0        0.0         381215.0
# 4              60.0                   0.0        0.0         439570.0
#
#    total_bal_ex_mort  total_bc_limit  total_il_high_credit_limit  \
# 0             7746.0          2400.0                     13734.0
# 1            39475.0         79300.0                     24667.0
# 2            18696.0          6200.0                     14877.0
# 3            52226.0         62500.0                     18000.0
# 4            95768.0         20300.0                     88097.0
#
#    revol_bal_joint  sec_app_fico_range_low  sec_app_fico_range_high  \
# 0              NaN                     NaN                      NaN
# 1              NaN                     NaN                      NaN
# 2              NaN                     NaN                      NaN
# 3              NaN                     NaN                      NaN
# 4              NaN                     NaN                      NaN
#
#    sec_app_earliest_cr_line  sec_app_inq_last_6mths  sec_app_mort_acc  \
# 0                       NaN                     NaN               NaN
# 1                       NaN                     NaN               NaN
# 2                       NaN                     NaN               NaN
# 3                       NaN                     NaN               NaN
# 4                       NaN                     NaN               NaN
#
#    sec_app_open_acc  sec_app_revol_util  sec_app_open_act_il  \
# 0               NaN                 NaN                  NaN
# 1               NaN                 NaN                  NaN
# 2               NaN                 NaN                  NaN
# 3               NaN                 NaN                  NaN
# 4               NaN                 NaN                  NaN
#
#    sec_app_num_rev_accts  sec_app_chargeoff_within_12_mths  \
# 0                    NaN                               NaN
# 1                    NaN                               NaN
# 2                    NaN                               NaN
# 3                    NaN                               NaN
# 4                    NaN                               NaN
#
#    sec_app_collections_12_mths_ex_med  sec_app_mths_since_last_major_derog  \
# 0                                 NaN                                  NaN
# 1                                 NaN                                  NaN
# 2                                 NaN                                  NaN
# 3                                 NaN                                  NaN
# 4                                 NaN                                  NaN
#
#   hardship_flag hardship_type hardship_reason hardship_status  deferral_term  \
# 0             N           NaN             NaN             NaN            NaN
# 1             N           NaN             NaN             NaN            NaN
# 2             N           NaN             NaN             NaN            NaN
# 3             N           NaN             NaN             NaN            NaN
# 4             N           NaN             NaN             NaN            NaN
#
#    hardship_amount hardship_start_date hardship_end_date  \
# 0              NaN                 NaN               NaN
# 1              NaN                 NaN               NaN
# 2              NaN                 NaN               NaN
# 3              NaN                 NaN               NaN
# 4              NaN                 NaN               NaN
#
#   payment_plan_start_date  hardship_length  hardship_dpd hardship_loan_status  \
# 0                     NaN              NaN           NaN                  NaN
# 1                     NaN              NaN           NaN                  NaN
# 2                     NaN              NaN           NaN                  NaN
# 3                     NaN              NaN           NaN                  NaN
# 4                     NaN              NaN           NaN                  NaN
#
#    orig_projected_additional_accrued_interest  hardship_payoff_balance_amount  \
# 0                                         NaN                             NaN
# 1                                         NaN                             NaN
# 2                                         NaN                             NaN
# 3                                         NaN                             NaN
# 4                                         NaN                             NaN
#
#    hardship_last_payment_amount disbursement_method debt_settlement_flag  \
# 0                           NaN                Cash                    N
# 1                           NaN                Cash                    N
# 2                           NaN                Cash                    N
# 3                           NaN                Cash                    N
# 4                           NaN                Cash                    N
#
#   debt_settlement_flag_date settlement_status settlement_date  \
# 0                       NaN               NaN             NaN
# 1                       NaN               NaN             NaN
# 2                       NaN               NaN             NaN
# 3                       NaN               NaN             NaN
# 4                       NaN               NaN             NaN
#
#    settlement_amount  settlement_percentage  settlement_term
# 0                NaN                    NaN              NaN
# 1                NaN                    NaN              NaN
# 2                NaN                    NaN              NaN
# 3                NaN                    NaN              NaN
# 4                NaN                    NaN              NaN

# %%
df.info(verbose=True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 151 columns):
#  #    Column                                      Non-Null Count   Dtype
# ---   ------                                      --------------   -----
#  0    id                                          100000 non-null  int64
#  1    member_id                                   0 non-null       float64
#  2    loan_amnt                                   100000 non-null  float64
#  3    funded_amnt                                 100000 non-null  float64
#  4    funded_amnt_inv                             100000 non-null  float64
#  5    term                                        100000 non-null  object
#  6    int_rate                                    100000 non-null  float64
#  7    installment                                 100000 non-null  float64
#  8    grade                                       100000 non-null  object
#  9    sub_grade                                   100000 non-null  object
#  10   emp_title                                   93893 non-null   object
#  11   emp_length                                  93918 non-null   object
#  12   home_ownership                              100000 non-null  object
#  13   annual_inc                                  100000 non-null  float64
#  14   verification_status                         100000 non-null  object
#  15   issue_d                                     100000 non-null  object
#  16   loan_status                                 100000 non-null  object
#  17   pymnt_plan                                  100000 non-null  object
#  18   url                                         100000 non-null  object
#  19   desc                                        7 non-null       object
#  20   purpose                                     100000 non-null  object
#  21   title                                       99872 non-null   object
#  22   zip_code                                    100000 non-null  object
#  23   addr_state                                  100000 non-null  object
#  24   dti                                         99998 non-null   float64
#  25   delinq_2yrs                                 100000 non-null  float64
#  26   earliest_cr_line                            100000 non-null  object
#  27   fico_range_low                              100000 non-null  float64
#  28   fico_range_high                             100000 non-null  float64
#  29   inq_last_6mths                              100000 non-null  float64
#  30   mths_since_last_delinq                      51846 non-null   float64
#  31   mths_since_last_record                      17713 non-null   float64
#  32   open_acc                                    100000 non-null  float64
#  33   pub_rec                                     100000 non-null  float64
#  34   revol_bal                                   100000 non-null  float64
#  35   revol_util                                  99960 non-null   float64
#  36   total_acc                                   100000 non-null  float64
#  37   initial_list_status                         100000 non-null  object
#  38   out_prncp                                   100000 non-null  float64
#  39   out_prncp_inv                               100000 non-null  float64
#  40   total_pymnt                                 100000 non-null  float64
#  41   total_pymnt_inv                             100000 non-null  float64
#  42   total_rec_prncp                             100000 non-null  float64
#  43   total_rec_int                               100000 non-null  float64
#  44   total_rec_late_fee                          100000 non-null  float64
#  45   recoveries                                  100000 non-null  float64
#  46   collection_recovery_fee                     100000 non-null  float64
#  47   last_pymnt_d                                99927 non-null   object
#  48   last_pymnt_amnt                             100000 non-null  float64
#  49   next_pymnt_d                                12663 non-null   object
#  50   last_credit_pull_d                          99997 non-null   object
#  51   last_fico_range_high                        100000 non-null  float64
#  52   last_fico_range_low                         100000 non-null  float64
#  53   collections_12_mths_ex_med                  100000 non-null  float64
#  54   mths_since_last_major_derog                 29371 non-null   float64
#  55   policy_code                                 100000 non-null  float64
#  56   application_type                            100000 non-null  object
#  57   annual_inc_joint                            484 non-null     float64
#  58   dti_joint                                   482 non-null     float64
#  59   verification_status_joint                   484 non-null     object
#  60   acc_now_delinq                              100000 non-null  float64
#  61   tot_coll_amt                                100000 non-null  float64
#  62   tot_cur_bal                                 100000 non-null  float64
#  63   open_acc_6m                                 20399 non-null   float64
#  64   open_act_il                                 20399 non-null   float64
#  65   open_il_12m                                 20399 non-null   float64
#  66   open_il_24m                                 20399 non-null   float64
#  67   mths_since_rcnt_il                          19864 non-null   float64
#  68   total_bal_il                                20399 non-null   float64
#  69   il_util                                     17776 non-null   float64
#  70   open_rv_12m                                 20399 non-null   float64
#  71   open_rv_24m                                 20399 non-null   float64
#  72   max_bal_bc                                  20399 non-null   float64
#  73   all_util                                    20399 non-null   float64
#  74   total_rev_hi_lim                            100000 non-null  float64
#  75   inq_fi                                      20399 non-null   float64
#  76   total_cu_tl                                 20399 non-null   float64
#  77   inq_last_12m                                20399 non-null   float64
#  78   acc_open_past_24mths                        100000 non-null  float64
#  79   avg_cur_bal                                 100000 non-null  float64
#  80   bc_open_to_buy                              99034 non-null   float64
#  81   bc_util                                     98984 non-null   float64
#  82   chargeoff_within_12_mths                    100000 non-null  float64
#  83   delinq_amnt                                 100000 non-null  float64
#  84   mo_sin_old_il_acct                          97227 non-null   float64
#  85   mo_sin_old_rev_tl_op                        100000 non-null  float64
#  86   mo_sin_rcnt_rev_tl_op                       100000 non-null  float64
#  87   mo_sin_rcnt_tl                              100000 non-null  float64
#  88   mort_acc                                    100000 non-null  float64
#  89   mths_since_recent_bc                        99073 non-null   float64
#  90   mths_since_recent_bc_dlq                    25442 non-null   float64
#  91   mths_since_recent_inq                       89239 non-null   float64
#  92   mths_since_recent_revol_delinq              35938 non-null   float64
#  93   num_accts_ever_120_pd                       100000 non-null  float64
#  94   num_actv_bc_tl                              100000 non-null  float64
#  95   num_actv_rev_tl                             100000 non-null  float64
#  96   num_bc_sats                                 100000 non-null  float64
#  97   num_bc_tl                                   100000 non-null  float64
#  98   num_il_tl                                   100000 non-null  float64
#  99   num_op_rev_tl                               100000 non-null  float64
#  100  num_rev_accts                               99999 non-null   float64
#  101  num_rev_tl_bal_gt_0                         100000 non-null  float64
#  102  num_sats                                    100000 non-null  float64
#  103  num_tl_120dpd_2m                            94735 non-null   float64
#  104  num_tl_30dpd                                100000 non-null  float64
#  105  num_tl_90g_dpd_24m                          100000 non-null  float64
#  106  num_tl_op_past_12m                          100000 non-null  float64
#  107  pct_tl_nvr_dlq                              100000 non-null  float64
#  108  percent_bc_gt_75                            98958 non-null   float64
#  109  pub_rec_bankruptcies                        100000 non-null  float64
#  110  tax_liens                                   100000 non-null  float64
#  111  tot_hi_cred_lim                             100000 non-null  float64
#  112  total_bal_ex_mort                           100000 non-null  float64
#  113  total_bc_limit                              100000 non-null  float64
#  114  total_il_high_credit_limit                  100000 non-null  float64
#  115  revol_bal_joint                             0 non-null       float64
#  116  sec_app_fico_range_low                      0 non-null       float64
#  117  sec_app_fico_range_high                     0 non-null       float64
#  118  sec_app_earliest_cr_line                    0 non-null       float64
#  119  sec_app_inq_last_6mths                      0 non-null       float64
#  120  sec_app_mort_acc                            0 non-null       float64
#  121  sec_app_open_acc                            0 non-null       float64
#  122  sec_app_revol_util                          0 non-null       float64
#  123  sec_app_open_act_il                         0 non-null       float64
#  124  sec_app_num_rev_accts                       0 non-null       float64
#  125  sec_app_chargeoff_within_12_mths            0 non-null       float64
#  126  sec_app_collections_12_mths_ex_med          0 non-null       float64
#  127  sec_app_mths_since_last_major_derog         0 non-null       float64
#  128  hardship_flag                               100000 non-null  object
#  129  hardship_type                               783 non-null     object
#  130  hardship_reason                             783 non-null     object
#  131  hardship_status                             783 non-null     object
#  132  deferral_term                               783 non-null     float64
#  133  hardship_amount                             783 non-null     float64
#  134  hardship_start_date                         783 non-null     object
#  135  hardship_end_date                           783 non-null     object
#  136  payment_plan_start_date                     783 non-null     object
#  137  hardship_length                             783 non-null     float64
#  138  hardship_dpd                                783 non-null     float64
#  139  hardship_loan_status                        783 non-null     object
#  140  orig_projected_additional_accrued_interest  627 non-null     float64
#  141  hardship_payoff_balance_amount              783 non-null     float64
#  142  hardship_last_payment_amount                783 non-null     float64
#  143  disbursement_method                         100000 non-null  object
#  144  debt_settlement_flag                        100000 non-null  object
#  145  debt_settlement_flag_date                   2897 non-null    object
#  146  settlement_status                           2897 non-null    object
#  147  settlement_date                             2897 non-null    object
#  148  settlement_amount                           2897 non-null    float64
#  149  settlement_percentage                       2897 non-null    float64
#  150  settlement_term                             2897 non-null    float64
# dtypes: float64(114), int64(1), object(36)
# memory usage: 115.2+ MB

# %%
df = df.drop(columns=['acc_open_past_24mths', 'all_util', 'bc_open_to_buy', 'chargeoff_within_12_mths', 'collection_recovery_fee', 'delinq_amnt', 'dti', 'dti_joint', 'fico_range_high',
                     'fico_range_low', 'grade', 'hardship_amount', 'hardship_dpd', 'hardship_end_date', 'hardship_flag', 'hardship_last_payment_amount', 'hardship_length', 'hardship_loan_status',
                     'hardship_payoff_balance_amount', 'hardship_reason', 'hardship_start_date', 'hardship_status', 'hardship_type', 'id', 'initial_list_status', 'inq_fi', 'inq_last_12m', 'inq_last_6mths',
                     'last_credit_pull_d', 'last_fico_range_high', 'last_fico_range_low', 'last_pymnt_amnt', 'last_pymnt_d', 'max_bal_bc',
                     'member_id', 'mo_sin_old_rev_tl_op', 'mo_sin_rcnt_rev_tl_op', 'mths_since_last_major_derog', 'mths_since_rcnt_il', 'mths_since_recent_bc_dlq', 'mths_since_recent_revol_delinq', 'next_pymnt_d', 
                     'num_accts_ever_120_pd', 'num_actv_rev_tl', 'num_il_tl', 'num_op_rev_tl', 'num_rev_accts', 'num_rev_tl_bal_gt_0', 'num_sats', 'num_tl_120dpd_2m', 'num_tl_30dpd', 'num_tl_90g_dpd_24m', 
                     'num_tl_op_past_12m', 'open_acc_6m', 'open_act_il', 'open_il_12m', 'open_il_24m', 'open_rv_12m', 'open_rv_24m', 'out_prncp', 'out_prncp_inv', 'orig_projected_additional_accrued_interest', 'pct_tl_nvr_dlq',
                     'policy_code', 'recoveries', 'revol_bal', 'revol_bal_joint', 'revol_util', 'sec_app_chargeoff_within_12_mths', 'sec_app_collections_12_mths_ex_med', 'sec_app_earliest_cr_line', 'sec_app_fico_range_high', 'sec_app_fico_range_low',
                     'sec_app_inq_last_6mths', 'sec_app_mort_acc', 'sec_app_mths_since_last_major_derog', 'sec_app_num_rev_accts', 'sec_app_open_acc', 'sec_app_open_act_il', 'sec_app_revol_util', 'settlement_amount', 'settlement_date', 'settlement_percentage',
                     'settlement_status', 'settlement_term', 'sub_grade', 'tax_liens', 'tot_coll_amt', 'tot_cur_bal', 'tot_hi_cred_lim', 'total_bal_ex_mort', 'total_bal_il', 'total_cu_tl', 'total_il_high_credit_limit', 'total_pymnt', 'total_pymnt_inv', 'total_rec_int', 
                     'total_rec_late_fee', 'total_rec_prncp', 'total_rev_hi_lim', 'url'])

# %%
df.info()

# %%
df = df.drop(columns=['annual_inc_joint', 'debt_settlement_flag_date', 'deferral_term', 'desc', 'payment_plan_start_date', 'verification_status_joint'])

# %%
df['loan_status'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>
